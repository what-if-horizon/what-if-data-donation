# %%
import json
import pandas as pd
import numpy as np
from pathlib import Path 
import re
import ast

# %%
main_path = "/home/rvissche/Nextcloud/What-If/what-if-data-donation/structure_donations/Processed_structure_donations/"
input_directory = Path(f'{main_path}TikTok/Input_test')  
print(input_directory)
max_columns = 7
# Out:
# /home/rvissche/Nextcloud/What-If/what-if-data-donation/structure_donations/Processed_structure_donations/TikTok/Input_test

# %%
for i in range(max_columns):
        col_path = [f"col_path_{i}" for i in range(max_columns)]
        col_path_values = [f"col_path_{i}_values" for i in range(1, max_columns)]
        col_path_list = [f"col_path_{i}_lIST" for i in range(1, max_columns)]

# %%
print(col_path_values)
# Out:
# ['col_path_1_values', 'col_path_2_values', 'col_path_3_values', 'col_path_4_values', 'col_path_5_values', 'col_path_6_values']

# %% [markdown]
# ### loading_data()

# %%
def loading_data(data):
    

    with open(data, 'r') as file:
        data = json.load(file)
    
    # Check the first (top-level) key
    first_key = next(iter(data))

    # If it ends with `.json`, unwrap the inner content
    if first_key.endswith(".json"):
        data = data[first_key]  # remove outer key

    df = pd.DataFrame()
    df['col_path_0_values'] = data
    df['col_path_0'] = df.index
    
   

    df.reset_index(inplace = True)
    df = df.drop('index', axis = 1)


        

    for i in range(1,max_columns):   
        df[f'col_path_{i}'] = ''
        df[f'col_path_{i}_values'] = ''
        df[f'col_path_{i}_LIST'] = ''


    
    return(df)

# %% [markdown]
# ### flatten_json()

# %%
def flatten_json(df):

    def add_rows(row, v, k, list_holder ):
        new_row = row.copy()
        new_row[f'col_path_{i+1}_values'] = v
        new_row[f'col_path_{i+1}'] = k
        new_row[f'col_path_{i+1}_LIST'] = list_holder
        return(new_row)
    
    new_rows = []
    current_rows = df.copy()  # snapshot to iterate over

    for ix, row in current_rows.iterrows():
        value= row['col_path_0_values']
            
        if isinstance(value, list):
                    # Check if list of dicts
            if value and isinstance(value[0], dict):
                
                seen = set()
                unique = []
                for d in value:
                    # Use json.dumps to get a hashable, sorted representation
                    s = json.dumps(d, sort_keys=True)
                    if s not in seen:
                        seen.add(s)
                        unique.append(d)
                value = unique
                

                for item in value:
                    new_row = row.copy()
                    new_row['col_path_0_values'] = item
                    new_row['col_path_0_LIST'] = 'LIST'
                    new_rows.append(new_row)
        else:
             df.at[ix, 'col_path_0_LIST'] = 'NO LIST'
    



    df = pd.concat([df, pd.DataFrame(new_rows)], ignore_index=True)
    
    new_rows.clear()

           

    new_rows = []

    for i in range(max_columns):
        current_rows = df.copy()  # snapshot to iterate over

        for ix, row in current_rows.iterrows():
            value = row.get(f'col_path_{i}_values', None)
    

            if isinstance(value, dict):
                for k, v in value.items():
                    if isinstance(v, list):
                        # Check if list of dicts
                        if v and isinstance(v[0], dict):

                            seen = set()
                            unique = []
                            for d in v:
                                # Use json.dumps to get a hashable, sorted representation
                                s = json.dumps(d, sort_keys=True)
                                if s not in seen:
                                    seen.add(s)
                                    unique.append(d)
                            v = unique
                            

                            for item in v:
                                new_row = add_rows(row, item, k, list_holder = 'LIST' )
                                new_rows.append(new_row)
                        else:
                            # Regular list (e.g., strings, ints)
                            v = v[0]
                            new_row = add_rows(row, v, k, list_holder = 'LIST')
                            new_rows.append(new_row)
                    else:
                
                        new_row = add_rows(row, v, k, list_holder = 'NO LIST' )
                        new_rows.append(new_row)
                

        df = pd.concat([df, pd.DataFrame(new_rows)], ignore_index=True)
        new_rows.clear()
            
                        


    

    df = df.replace(r'^\s*$', np.nan, regex=True)
    df_red = df.drop(columns=[col for col in df.columns if col.endswith("_LIST")])
    
    df_red['last_valid_index'] = df_red.apply(pd.Series.last_valid_index, axis=1)
    df_red = df_red.drop(columns=[col for col in df.columns if col.endswith("values")])

    
    col_path = [f"col_path_{i}" for i in range(max_columns)]
    df = pd.merge(df, df_red, on = col_path, how='left')
    
    
    return(df)

# %% [markdown]
# ### process_col_path()
# The 'process_col_path()' function checks whether the value in a row of for one of the column paths is actually a datatype and stores this value in a column data_type and replaces the original value with NA. The data types are the lowest level values in the JSON files

# %%
# Define the data types
data_types = ['string', 'array', 'number', 'boolean', 'object', 'str', 'int', 'float', 'bool', 'dict', 'list']



# Define the function 'process_col_path()'
def process_col_path(df, col_path_values, data_types):
    df['data_type'] = ''

    """
    row: Rows in the dataframe
    columns: List of column names of column path columns 
    data_types: List of the values that are data types
    """
    
    for ix, row in df.iterrows():
        for col in [f"col_path_{i}_values" for i in range(1, max_columns)]:
            

            #If the value stored in the column is found in the list 'data_types', 
            if row[col] in data_types:
                # this value is placed in the column 'data_type'
                value = row[col]
                
                df.at[ix, 'data_type'] = value
            else:
                continue
               
    
                
    return df

# %% [markdown]
# ### remove_intermediate_rows()

# %%
def remove_intermediate_rows(df):
    drop_index = []
    for ix, row in df.iterrows():
            last_value = row[f"{row['last_valid_index']}"]
           
        
            if isinstance(last_value, str):
                if last_value not in (data_types):
                        #col =  row['last_valid_index']
                        #col_level = re.findall(r'\d+', col)
                        #col_level = col_level[0]       
                        #df.at[ix, f"col_path_{col_level}_LIST"] = np.nan

                        drop_index.append(ix)
            else:
                drop_index.append(ix)
                  
        
   
    df = df.drop(drop_index)
    df = df.drop(columns=[col for col in df.columns if col.endswith("values")])

    
    return df

# %% [markdown]
# ### extract_path()

# %%
def extract_path(df, max_columns):
    
    df['path']= ''
    
    for ix, row in df.iterrows():
        path = []
    
        for col in [f"col_path_{i}" for i in range(max_columns)]:
            val = row[col]
        
            if pd.notna(val):

                path.append(str(val).strip())

      
        
        df.at[ix, 'path'] = path
       
    
        

    return df

# %% [markdown]
# ### list_path()

# %%
def list_path(df):
    
    df['list_path'] = ''
    df['subfield_path'] = ''
    df['column_name'] = ''
    df['var_type'] = ''
    
    new_rows = []
    delete_rows = []

    for ix, row in df.iterrows():
        
        path = row['path'] 
        found_list = False
        
        
        for i in reversed(range(len(path))):
           
            if row[f"col_path_{i}_LIST"] == 'LIST':
                
                new_row = row.copy()
                delete_rows.append(ix)
                new_row['var_type'] = 'list'
                new_row['list_path'] = path[:i+1]
                new_row['subfield_path'] = path[i+1:]
                new_row['column_name'] = path[-1]
                new_rows.append(new_row)
                found_list = True
                break

            elif row[f"col_path_{i}_LIST"] == "NO LIST":
                var_type = 'static'
                subfield_path = path
                column_name = path[-1]
                

            elif row[f"col_path_{i}_LIST"] == 'nan':
                var_type = 'skip'
                subfield_path = path
                column_name = path[-1]
               
            else:
                var_type = 'skip'
                subfield_path = path
                column_name = path[-1]


        if not found_list:   
            df.at[ix, 'subfield_path'] = subfield_path
            df.at[ix, 'column_name'] = column_name
            df.at[ix, 'var_type'] = var_type

    df = df.drop(index=delete_rows).reset_index(drop=True)
    df = pd.concat([df, pd.DataFrame(new_rows)], ignore_index=True)
    new_rows.clear()
    
        


    
      
        
    return df

# %% [markdown]
# ### clean_and_store()
# This function orders the columns in the DataFrame, resets the index, fills the NA and saves the DataFrame as CSV

# %%
def clean_and_store(df, file_name):

    """
    df: The dataframe that will be cleaned and stored
    file_name: The filename of data structure that is being processed
    """

  
   
    df=  df[df['col_path_0'] != 'Direct Message']
    
    
  
    df = df[['column_name', 'path', 'list_path', 'subfield_path', 'var_type', 'data_type']]
    # Save the DataFrame 
    df.to_csv(f"{main_path}TikTok/Output/Output_" + file_name + '.csv', index=False)

    return df

# %% [markdown]
# ### structure_donations()
# The structure_donations() function executes all functions above and results in a saved DataFrame for each data structure.

# %%
def structure_donations(data, col_path, max_columns):
     # Store the path to the data structure
    data = Path(data)  
    
    # Save teh file name of the data structure
    file_name = Path(data).stem 

    df = loading_data(data)
    print('FINISH: loading_data()')
  
    df = flatten_json(df)
    print('FINISH: flatten_json()')
    df = process_col_path(df, col_path_values, data_types)
    print('FINISH: process_col_path()')
    df = remove_intermediate_rows(df)
    print('FINISH: remove_intermediate_rows()')
    df = extract_path(df, max_columns)
    print('FINISH: extract_path()')
    df = list_path(df)
    print('FINISH: list_path()')

    display(df)
    df = clean_and_store(df, file_name)
    print('FINISH: clean_and_store()')

    return(df)

# %% [markdown]
# ## Execute 'structure_donations()': Transform data structures from JSON format to tabular format

# %%
# Execute the 'structure_donations()' function for each file (data structure) in the input directory
for file in input_directory.iterdir():  
    if file.is_file():  
        print(file.name)
        structure_donations(file, col_path, max_columns)
# Out:
# HJ_tiktol_json_strcure.json
# FINISH: loading_data()
# FINISH: flatten_json()
# FINISH: process_col_path()
# FINISH: remove_intermediate_rows()
# FINISH: extract_path()
# FINISH: list_path()
# /tmp/ipykernel_24409/2138702084.py:96: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace(r'^\s*$', np.nan, regex=True)
#          col_path_0                  col_path_1 col_path_1_LIST  \
# 0      Ads and data                Ad Interests         NO LIST
# 1      Ads and data  Instant Form Ads Responses         NO LIST
# 2      Ads and data         Off TikTok Activity         NO LIST
# 3      App Settings                  Block List         NO LIST
# 4      App Settings                  Block List         NO LIST
# ..              ...                         ...             ...
# 153  Direct Message             Direct Messages         NO LIST
# 154  Direct Message             Direct Messages         NO LIST
# 155  Direct Message             Direct Messages         NO LIST
# 156  Direct Message             Direct Messages         NO LIST
# 157  Direct Message             Direct Messages         NO LIST
#
#                     col_path_2 col_path_2_LIST  \
# 0         AdInterestCategories         NO LIST
# 1                ResponsesList         NO LIST
# 2    OffTikTokActivityDataList         NO LIST
# 3                          App         NO LIST
# 4                    BlockList         NO LIST
# ..                         ...             ...
# 153                ChatHistory         NO LIST
# 154                ChatHistory         NO LIST
# 155                ChatHistory         NO LIST
# 156                ChatHistory         NO LIST
# 157                ChatHistory         NO LIST
#
#                             col_path_3 col_path_3_LIST col_path_4  \
# 0                                  NaN             NaN        NaN
# 1                                  NaN             NaN        NaN
# 2                                  NaN             NaN        NaN
# 3                                  NaN             NaN        NaN
# 4                                  NaN             NaN        NaN
# ..                                 ...             ...        ...
# 153  Chat History with jannemertens99:            LIST       From
# 154  Chat History with jannemertens99:            LIST    Content
# 155  Chat History with nynkeveenstraa:            LIST       Date
# 156  Chat History with nynkeveenstraa:            LIST       From
# 157  Chat History with nynkeveenstraa:            LIST    Content
#
#     col_path_4_LIST  col_path_5  ...  col_path_6  col_path_6_LIST  \
# 0               NaN         NaN  ...         NaN              NaN
# 1               NaN         NaN  ...         NaN              NaN
# 2               NaN         NaN  ...         NaN              NaN
# 3               NaN         NaN  ...         NaN              NaN
# 4               NaN         NaN  ...         NaN              NaN
# ..              ...         ...  ...         ...              ...
# 153         NO LIST         NaN  ...         NaN              NaN
# 154         NO LIST         NaN  ...         NaN              NaN
# 155         NO LIST         NaN  ...         NaN              NaN
# 156         NO LIST         NaN  ...         NaN              NaN
# 157         NO LIST         NaN  ...         NaN              NaN
#
#      col_path_0_LIST   last_valid_index data_type  \
# 0            NO LIST  col_path_2_values    string
# 1            NO LIST  col_path_2_values    object
# 2            NO LIST  col_path_2_values    object
# 3            NO LIST  col_path_2_values    number
# 4            NO LIST  col_path_2_values    object
# ..               ...                ...       ...
# 153          NO LIST  col_path_4_values    string
# 154          NO LIST  col_path_4_values    string
# 155          NO LIST  col_path_4_values    string
# 156          NO LIST  col_path_4_values    string
# 157          NO LIST  col_path_4_values    string
#
#                                                   path  \
# 0    [Ads and data, Ad Interests, AdInterestCategor...
# 1    [Ads and data, Instant Form Ads Responses, Res...
# 2    [Ads and data, Off TikTok Activity, OffTikTokA...
# 3                      [App Settings, Block List, App]
# 4                [App Settings, Block List, BlockList]
# ..                                                 ...
# 153  [Direct Message, Direct Messages, ChatHistory,...
# 154  [Direct Message, Direct Messages, ChatHistory,...
# 155  [Direct Message, Direct Messages, ChatHistory,...
# 156  [Direct Message, Direct Messages, ChatHistory,...
# 157  [Direct Message, Direct Messages, ChatHistory,...
#
#                                              list_path  \
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 153  [Direct Message, Direct Messages, ChatHistory,...
# 154  [Direct Message, Direct Messages, ChatHistory,...
# 155  [Direct Message, Direct Messages, ChatHistory,...
# 156  [Direct Message, Direct Messages, ChatHistory,...
# 157  [Direct Message, Direct Messages, ChatHistory,...
#
#                                          subfield_path  \
# 0    [Ads and data, Ad Interests, AdInterestCategor...
# 1    [Ads and data, Instant Form Ads Responses, Res...
# 2    [Ads and data, Off TikTok Activity, OffTikTokA...
# 3                      [App Settings, Block List, App]
# 4                [App Settings, Block List, BlockList]
# ..                                                 ...
# 153                                             [From]
# 154                                          [Content]
# 155                                             [Date]
# 156                                             [From]
# 157                                          [Content]
#
#                    column_name var_type
# 0         AdInterestCategories   static
# 1                ResponsesList   static
# 2    OffTikTokActivityDataList   static
# 3                          App   static
# 4                    BlockList   static
# ..                         ...      ...
# 153                       From     list
# 154                    Content     list
# 155                       Date     list
# 156                       From     list
# 157                    Content     list
#
# [158 rows x 21 columns]
# FINISH: clean_and_store()
# TT_structure_tiktok_takeout_ro.json
# FINISH: loading_data()
# FINISH: flatten_json()
# FINISH: process_col_path()
# FINISH: remove_intermediate_rows()
# FINISH: extract_path()
# FINISH: list_path()
# /tmp/ipykernel_24409/2138702084.py:96: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace(r'^\s*$', np.nan, regex=True)
#     col_path_0           col_path_1 col_path_1_LIST  col_path_2  \
# 0     Activity      Favorite Videos         NO LIST         App
# 1     Activity        Follower List         NO LIST         App
# 2     Activity        Follower List         NO LIST  IsFastLane
# 3     Activity       Following List         NO LIST         App
# 4     Activity       Following List         NO LIST  IsFastLane
# ..         ...                  ...             ...         ...
# 126      Video               Videos         NO LIST   VideoList
# 127    Profile  Profile Information         NO LIST  ProfileMap
# 128    Profile  Profile Information         NO LIST  ProfileMap
# 129    Profile  Profile Information         NO LIST  ProfileMap
# 130    Profile  Profile Information         NO LIST  ProfileMap
#
#     col_path_2_LIST    col_path_3 col_path_3_LIST     col_path_4  \
# 0           NO LIST           NaN             NaN            NaN
# 1           NO LIST           NaN             NaN            NaN
# 2           NO LIST           NaN             NaN            NaN
# 3           NO LIST           NaN             NaN            NaN
# 4           NO LIST           NaN             NaN            NaN
# ..              ...           ...             ...            ...
# 126            LIST  AddYoursText         NO LIST            NaN
# 127         NO LIST  PlatformInfo            LIST    Description
# 128         NO LIST  PlatformInfo            LIST           Name
# 129         NO LIST  PlatformInfo            LIST       Platform
# 130         NO LIST  PlatformInfo            LIST  Profile Photo
#
#     col_path_4_LIST  col_path_5  ...  col_path_6  col_path_6_LIST  \
# 0               NaN         NaN  ...         NaN              NaN
# 1               NaN         NaN  ...         NaN              NaN
# 2               NaN         NaN  ...         NaN              NaN
# 3               NaN         NaN  ...         NaN              NaN
# 4               NaN         NaN  ...         NaN              NaN
# ..              ...         ...  ...         ...              ...
# 126             NaN         NaN  ...         NaN              NaN
# 127         NO LIST         NaN  ...         NaN              NaN
# 128         NO LIST         NaN  ...         NaN              NaN
# 129         NO LIST         NaN  ...         NaN              NaN
# 130         NO LIST         NaN  ...         NaN              NaN
#
#      col_path_0_LIST   last_valid_index data_type  \
# 0            NO LIST  col_path_2_values    number
# 1            NO LIST  col_path_2_values    number
# 2            NO LIST  col_path_2_values   boolean
# 3            NO LIST  col_path_2_values    number
# 4            NO LIST  col_path_2_values   boolean
# ..               ...                ...       ...
# 126          NO LIST  col_path_3_values    string
# 127          NO LIST  col_path_4_values    string
# 128          NO LIST  col_path_4_values    string
# 129          NO LIST  col_path_4_values    string
# 130          NO LIST  col_path_4_values    string
#
#                                                   path  \
# 0                     [Activity, Favorite Videos, App]
# 1                       [Activity, Follower List, App]
# 2                [Activity, Follower List, IsFastLane]
# 3                      [Activity, Following List, App]
# 4               [Activity, Following List, IsFastLane]
# ..                                                 ...
# 126           [Video, Videos, VideoList, AddYoursText]
# 127  [Profile, Profile Information, ProfileMap, Pla...
# 128  [Profile, Profile Information, ProfileMap, Pla...
# 129  [Profile, Profile Information, ProfileMap, Pla...
# 130  [Profile, Profile Information, ProfileMap, Pla...
#
#                                              list_path  \
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 126                         [Video, Videos, VideoList]
# 127  [Profile, Profile Information, ProfileMap, Pla...
# 128  [Profile, Profile Information, ProfileMap, Pla...
# 129  [Profile, Profile Information, ProfileMap, Pla...
# 130  [Profile, Profile Information, ProfileMap, Pla...
#
#                               subfield_path    column_name var_type
# 0          [Activity, Favorite Videos, App]            App   static
# 1            [Activity, Follower List, App]            App   static
# 2     [Activity, Follower List, IsFastLane]     IsFastLane   static
# 3           [Activity, Following List, App]            App   static
# 4    [Activity, Following List, IsFastLane]     IsFastLane   static
# ..                                      ...            ...      ...
# 126                          [AddYoursText]   AddYoursText     list
# 127                           [Description]    Description     list
# 128                                  [Name]           Name     list
# 129                              [Platform]       Platform     list
# 130                         [Profile Photo]  Profile Photo     list
#
# [131 rows x 21 columns]
# FINISH: clean_and_store()
# extra_tiktok_json_structure.json
# FINISH: loading_data()
# FINISH: flatten_json()
# FINISH: process_col_path()
# FINISH: remove_intermediate_rows()
# FINISH: extract_path()
# FINISH: list_path()
# /tmp/ipykernel_24409/2138702084.py:96: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace(r'^\s*$', np.nan, regex=True)
#         col_path_0                  col_path_1 col_path_1_LIST  \
# 0     Ads and data                Ad Interests         NO LIST
# 1     Ads and data  Instant Form Ads Responses         NO LIST
# 2     Ads and data         Off TikTok Activity         NO LIST
# 3     App Settings                  Block List         NO LIST
# 4     App Settings                  Block List         NO LIST
# ..             ...                         ...             ...
# 122  Your Activity                      Status         NO LIST
# 123  Your Activity                      Status         NO LIST
# 124  Your Activity                      Status         NO LIST
# 125  Your Activity               Watch History         NO LIST
# 126  Your Activity               Watch History         NO LIST
#
#                     col_path_2 col_path_2_LIST  col_path_3 col_path_3_LIST  \
# 0         AdInterestCategories         NO LIST         NaN             NaN
# 1                ResponsesList         NO LIST         NaN             NaN
# 2    OffTikTokActivityDataList         NO LIST         NaN             NaN
# 3                          App         NO LIST         NaN             NaN
# 4                    BlockList         NO LIST         NaN             NaN
# ..                         ...             ...         ...             ...
# 122                Status List            LIST  Android ID         NO LIST
# 123                Status List            LIST        IDFV         NO LIST
# 124                Status List            LIST      Web ID         NO LIST
# 125                  VideoList            LIST        Date         NO LIST
# 126                  VideoList            LIST        Link         NO LIST
#
#     col_path_4 col_path_4_LIST  col_path_5  ...  col_path_6  col_path_6_LIST  \
# 0          NaN             NaN         NaN  ...         NaN              NaN
# 1          NaN             NaN         NaN  ...         NaN              NaN
# 2          NaN             NaN         NaN  ...         NaN              NaN
# 3          NaN             NaN         NaN  ...         NaN              NaN
# 4          NaN             NaN         NaN  ...         NaN              NaN
# ..         ...             ...         ...  ...         ...              ...
# 122        NaN             NaN         NaN  ...         NaN              NaN
# 123        NaN             NaN         NaN  ...         NaN              NaN
# 124        NaN             NaN         NaN  ...         NaN              NaN
# 125        NaN             NaN         NaN  ...         NaN              NaN
# 126        NaN             NaN         NaN  ...         NaN              NaN
#
#      col_path_0_LIST   last_valid_index data_type  \
# 0            NO LIST  col_path_2_values    string
# 1            NO LIST  col_path_2_values    object
# 2            NO LIST  col_path_2_values    object
# 3            NO LIST  col_path_2_values    number
# 4            NO LIST  col_path_2_values    object
# ..               ...                ...       ...
# 122          NO LIST  col_path_3_values    string
# 123          NO LIST  col_path_3_values    string
# 124          NO LIST  col_path_3_values    string
# 125          NO LIST  col_path_3_values    string
# 126          NO LIST  col_path_3_values    string
#
#                                                   path  \
# 0    [Ads and data, Ad Interests, AdInterestCategor...
# 1    [Ads and data, Instant Form Ads Responses, Res...
# 2    [Ads and data, Off TikTok Activity, OffTikTokA...
# 3                      [App Settings, Block List, App]
# 4                [App Settings, Block List, BlockList]
# ..                                                 ...
# 122   [Your Activity, Status, Status List, Android ID]
# 123         [Your Activity, Status, Status List, IDFV]
# 124       [Your Activity, Status, Status List, Web ID]
# 125    [Your Activity, Watch History, VideoList, Date]
# 126    [Your Activity, Watch History, VideoList, Link]
#
#                                      list_path  \
# 0
# 1
# 2
# 3
# 4
# ..                                         ...
# 122       [Your Activity, Status, Status List]
# 123       [Your Activity, Status, Status List]
# 124       [Your Activity, Status, Status List]
# 125  [Your Activity, Watch History, VideoList]
# 126  [Your Activity, Watch History, VideoList]
#
#                                          subfield_path  \
# 0    [Ads and data, Ad Interests, AdInterestCategor...
# 1    [Ads and data, Instant Form Ads Responses, Res...
# 2    [Ads and data, Off TikTok Activity, OffTikTokA...
# 3                      [App Settings, Block List, App]
# 4                [App Settings, Block List, BlockList]
# ..                                                 ...
# 122                                       [Android ID]
# 123                                             [IDFV]
# 124                                           [Web ID]
# 125                                             [Date]
# 126                                             [Link]
#
#                    column_name var_type
# 0         AdInterestCategories   static
# 1                ResponsesList   static
# 2    OffTikTokActivityDataList   static
# 3                          App   static
# 4                    BlockList   static
# ..                         ...      ...
# 122                 Android ID     list
# 123                       IDFV     list
# 124                     Web ID     list
# 125                       Date     list
# 126                       Link     list
#
# [127 rows x 21 columns]
# FINISH: clean_and_store()
# TT_structure_tiktok_takeout_es.json
# FINISH: loading_data()
# FINISH: flatten_json()
# FINISH: process_col_path()
# FINISH: remove_intermediate_rows()
# FINISH: extract_path()
# FINISH: list_path()
# /tmp/ipykernel_24409/2138702084.py:96: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace(r'^\s*$', np.nan, regex=True)
#     col_path_0           col_path_1 col_path_1_LIST  col_path_2  \
# 0     Activity      Favorite Videos         NO LIST         App
# 1     Activity        Follower List         NO LIST         App
# 2     Activity        Follower List         NO LIST  IsFastLane
# 3     Activity       Following List         NO LIST         App
# 4     Activity       Following List         NO LIST  IsFastLane
# ..         ...                  ...             ...         ...
# 126      Video               Videos         NO LIST   VideoList
# 127    Profile  Profile Information         NO LIST  ProfileMap
# 128    Profile  Profile Information         NO LIST  ProfileMap
# 129    Profile  Profile Information         NO LIST  ProfileMap
# 130    Profile  Profile Information         NO LIST  ProfileMap
#
#     col_path_2_LIST    col_path_3 col_path_3_LIST     col_path_4  \
# 0           NO LIST           NaN             NaN            NaN
# 1           NO LIST           NaN             NaN            NaN
# 2           NO LIST           NaN             NaN            NaN
# 3           NO LIST           NaN             NaN            NaN
# 4           NO LIST           NaN             NaN            NaN
# ..              ...           ...             ...            ...
# 126            LIST  AddYoursText         NO LIST            NaN
# 127         NO LIST  PlatformInfo            LIST    Description
# 128         NO LIST  PlatformInfo            LIST           Name
# 129         NO LIST  PlatformInfo            LIST       Platform
# 130         NO LIST  PlatformInfo            LIST  Profile Photo
#
#     col_path_4_LIST  col_path_5  ...  col_path_6  col_path_6_LIST  \
# 0               NaN         NaN  ...         NaN              NaN
# 1               NaN         NaN  ...         NaN              NaN
# 2               NaN         NaN  ...         NaN              NaN
# 3               NaN         NaN  ...         NaN              NaN
# 4               NaN         NaN  ...         NaN              NaN
# ..              ...         ...  ...         ...              ...
# 126             NaN         NaN  ...         NaN              NaN
# 127         NO LIST         NaN  ...         NaN              NaN
# 128         NO LIST         NaN  ...         NaN              NaN
# 129         NO LIST         NaN  ...         NaN              NaN
# 130         NO LIST         NaN  ...         NaN              NaN
#
#      col_path_0_LIST   last_valid_index data_type  \
# 0            NO LIST  col_path_2_values    number
# 1            NO LIST  col_path_2_values    number
# 2            NO LIST  col_path_2_values   boolean
# 3            NO LIST  col_path_2_values    number
# 4            NO LIST  col_path_2_values   boolean
# ..               ...                ...       ...
# 126          NO LIST  col_path_3_values    string
# 127          NO LIST  col_path_4_values    string
# 128          NO LIST  col_path_4_values    string
# 129          NO LIST  col_path_4_values    string
# 130          NO LIST  col_path_4_values    string
#
#                                                   path  \
# 0                     [Activity, Favorite Videos, App]
# 1                       [Activity, Follower List, App]
# 2                [Activity, Follower List, IsFastLane]
# 3                      [Activity, Following List, App]
# 4               [Activity, Following List, IsFastLane]
# ..                                                 ...
# 126           [Video, Videos, VideoList, AddYoursText]
# 127  [Profile, Profile Information, ProfileMap, Pla...
# 128  [Profile, Profile Information, ProfileMap, Pla...
# 129  [Profile, Profile Information, ProfileMap, Pla...
# 130  [Profile, Profile Information, ProfileMap, Pla...
#
#                                              list_path  \
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 126                         [Video, Videos, VideoList]
# 127  [Profile, Profile Information, ProfileMap, Pla...
# 128  [Profile, Profile Information, ProfileMap, Pla...
# 129  [Profile, Profile Information, ProfileMap, Pla...
# 130  [Profile, Profile Information, ProfileMap, Pla...
#
#                               subfield_path    column_name var_type
# 0          [Activity, Favorite Videos, App]            App   static
# 1            [Activity, Follower List, App]            App   static
# 2     [Activity, Follower List, IsFastLane]     IsFastLane   static
# 3           [Activity, Following List, App]            App   static
# 4    [Activity, Following List, IsFastLane]     IsFastLane   static
# ..                                      ...            ...      ...
# 126                          [AddYoursText]   AddYoursText     list
# 127                           [Description]    Description     list
# 128                                  [Name]           Name     list
# 129                              [Platform]       Platform     list
# 130                         [Profile Photo]  Profile Photo     list
#
# [131 rows x 21 columns]
# FINISH: clean_and_store()
# TT_structure_user_data_tiktok.json
# FINISH: loading_data()
# FINISH: flatten_json()
# FINISH: process_col_path()
# FINISH: remove_intermediate_rows()
# FINISH: extract_path()
# FINISH: list_path()
# /tmp/ipykernel_24409/2138702084.py:96: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace(r'^\s*$', np.nan, regex=True)
#     col_path_0           col_path_1 col_path_1_LIST  col_path_2  \
# 0     Activity      Favorite Videos         NO LIST         App
# 1     Activity        Follower List         NO LIST         App
# 2     Activity        Follower List         NO LIST  IsFastLane
# 3     Activity       Following List         NO LIST         App
# 4     Activity       Following List         NO LIST  IsFastLane
# ..         ...                  ...             ...         ...
# 137      Video               Videos         NO LIST   VideoList
# 138    Profile  Profile Information         NO LIST  ProfileMap
# 139    Profile  Profile Information         NO LIST  ProfileMap
# 140    Profile  Profile Information         NO LIST  ProfileMap
# 141    Profile  Profile Information         NO LIST  ProfileMap
#
#     col_path_2_LIST    col_path_3 col_path_3_LIST     col_path_4  \
# 0           NO LIST           NaN             NaN            NaN
# 1           NO LIST           NaN             NaN            NaN
# 2           NO LIST           NaN             NaN            NaN
# 3           NO LIST           NaN             NaN            NaN
# 4           NO LIST           NaN             NaN            NaN
# ..              ...           ...             ...            ...
# 137            LIST  AddYoursText         NO LIST            NaN
# 138         NO LIST  PlatformInfo            LIST    Description
# 139         NO LIST  PlatformInfo            LIST           Name
# 140         NO LIST  PlatformInfo            LIST       Platform
# 141         NO LIST  PlatformInfo            LIST  Profile Photo
#
#     col_path_4_LIST  col_path_5  ...  col_path_6  col_path_6_LIST  \
# 0               NaN         NaN  ...         NaN              NaN
# 1               NaN         NaN  ...         NaN              NaN
# 2               NaN         NaN  ...         NaN              NaN
# 3               NaN         NaN  ...         NaN              NaN
# 4               NaN         NaN  ...         NaN              NaN
# ..              ...         ...  ...         ...              ...
# 137             NaN         NaN  ...         NaN              NaN
# 138         NO LIST         NaN  ...         NaN              NaN
# 139         NO LIST         NaN  ...         NaN              NaN
# 140         NO LIST         NaN  ...         NaN              NaN
# 141         NO LIST         NaN  ...         NaN              NaN
#
#      col_path_0_LIST   last_valid_index data_type  \
# 0            NO LIST  col_path_2_values    number
# 1            NO LIST  col_path_2_values    number
# 2            NO LIST  col_path_2_values   boolean
# 3            NO LIST  col_path_2_values    number
# 4            NO LIST  col_path_2_values   boolean
# ..               ...                ...       ...
# 137          NO LIST  col_path_3_values    string
# 138          NO LIST  col_path_4_values    string
# 139          NO LIST  col_path_4_values    string
# 140          NO LIST  col_path_4_values    string
# 141          NO LIST  col_path_4_values    string
#
#                                                   path  \
# 0                     [Activity, Favorite Videos, App]
# 1                       [Activity, Follower List, App]
# 2                [Activity, Follower List, IsFastLane]
# 3                      [Activity, Following List, App]
# 4               [Activity, Following List, IsFastLane]
# ..                                                 ...
# 137           [Video, Videos, VideoList, AddYoursText]
# 138  [Profile, Profile Information, ProfileMap, Pla...
# 139  [Profile, Profile Information, ProfileMap, Pla...
# 140  [Profile, Profile Information, ProfileMap, Pla...
# 141  [Profile, Profile Information, ProfileMap, Pla...
#
#                                              list_path  \
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 137                         [Video, Videos, VideoList]
# 138  [Profile, Profile Information, ProfileMap, Pla...
# 139  [Profile, Profile Information, ProfileMap, Pla...
# 140  [Profile, Profile Information, ProfileMap, Pla...
# 141  [Profile, Profile Information, ProfileMap, Pla...
#
#                               subfield_path    column_name var_type
# 0          [Activity, Favorite Videos, App]            App   static
# 1            [Activity, Follower List, App]            App   static
# 2     [Activity, Follower List, IsFastLane]     IsFastLane   static
# 3           [Activity, Following List, App]            App   static
# 4    [Activity, Following List, IsFastLane]     IsFastLane   static
# ..                                      ...            ...      ...
# 137                          [AddYoursText]   AddYoursText     list
# 138                           [Description]    Description     list
# 139                                  [Name]           Name     list
# 140                              [Platform]       Platform     list
# 141                         [Profile Photo]  Profile Photo     list
#
# [142 rows x 21 columns]
# FINISH: clean_and_store()
# TT_structure_tiktok_takeout_dutch.json
# FINISH: loading_data()
# /tmp/ipykernel_24409/2138702084.py:96: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace(r'^\s*$', np.nan, regex=True)
# FINISH: flatten_json()
# FINISH: process_col_path()
# FINISH: remove_intermediate_rows()
# FINISH: extract_path()
# FINISH: list_path()
#     col_path_0           col_path_1 col_path_1_LIST  col_path_2  \
# 0     Activity      Favorite Videos         NO LIST         App
# 1     Activity        Follower List         NO LIST         App
# 2     Activity        Follower List         NO LIST  IsFastLane
# 3     Activity       Following List         NO LIST         App
# 4     Activity       Following List         NO LIST  IsFastLane
# ..         ...                  ...             ...         ...
# 126      Video               Videos         NO LIST   VideoList
# 127    Profile  Profile Information         NO LIST  ProfileMap
# 128    Profile  Profile Information         NO LIST  ProfileMap
# 129    Profile  Profile Information         NO LIST  ProfileMap
# 130    Profile  Profile Information         NO LIST  ProfileMap
#
#     col_path_2_LIST    col_path_3 col_path_3_LIST     col_path_4  \
# 0           NO LIST           NaN             NaN            NaN
# 1           NO LIST           NaN             NaN            NaN
# 2           NO LIST           NaN             NaN            NaN
# 3           NO LIST           NaN             NaN            NaN
# 4           NO LIST           NaN             NaN            NaN
# ..              ...           ...             ...            ...
# 126            LIST  AddYoursText         NO LIST            NaN
# 127         NO LIST  PlatformInfo            LIST    Description
# 128         NO LIST  PlatformInfo            LIST           Name
# 129         NO LIST  PlatformInfo            LIST       Platform
# 130         NO LIST  PlatformInfo            LIST  Profile Photo
#
#     col_path_4_LIST  col_path_5  ...  col_path_6  col_path_6_LIST  \
# 0               NaN         NaN  ...         NaN              NaN
# 1               NaN         NaN  ...         NaN              NaN
# 2               NaN         NaN  ...         NaN              NaN
# 3               NaN         NaN  ...         NaN              NaN
# 4               NaN         NaN  ...         NaN              NaN
# ..              ...         ...  ...         ...              ...
# 126             NaN         NaN  ...         NaN              NaN
# 127         NO LIST         NaN  ...         NaN              NaN
# 128         NO LIST         NaN  ...         NaN              NaN
# 129         NO LIST         NaN  ...         NaN              NaN
# 130         NO LIST         NaN  ...         NaN              NaN
#
#      col_path_0_LIST   last_valid_index data_type  \
# 0            NO LIST  col_path_2_values    number
# 1            NO LIST  col_path_2_values    number
# 2            NO LIST  col_path_2_values   boolean
# 3            NO LIST  col_path_2_values    number
# 4            NO LIST  col_path_2_values   boolean
# ..               ...                ...       ...
# 126          NO LIST  col_path_3_values    string
# 127          NO LIST  col_path_4_values    string
# 128          NO LIST  col_path_4_values    string
# 129          NO LIST  col_path_4_values    string
# 130          NO LIST  col_path_4_values    string
#
#                                                   path  \
# 0                     [Activity, Favorite Videos, App]
# 1                       [Activity, Follower List, App]
# 2                [Activity, Follower List, IsFastLane]
# 3                      [Activity, Following List, App]
# 4               [Activity, Following List, IsFastLane]
# ..                                                 ...
# 126           [Video, Videos, VideoList, AddYoursText]
# 127  [Profile, Profile Information, ProfileMap, Pla...
# 128  [Profile, Profile Information, ProfileMap, Pla...
# 129  [Profile, Profile Information, ProfileMap, Pla...
# 130  [Profile, Profile Information, ProfileMap, Pla...
#
#                                              list_path  \
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 126                         [Video, Videos, VideoList]
# 127  [Profile, Profile Information, ProfileMap, Pla...
# 128  [Profile, Profile Information, ProfileMap, Pla...
# 129  [Profile, Profile Information, ProfileMap, Pla...
# 130  [Profile, Profile Information, ProfileMap, Pla...
#
#                               subfield_path    column_name var_type
# 0          [Activity, Favorite Videos, App]            App   static
# 1            [Activity, Follower List, App]            App   static
# 2     [Activity, Follower List, IsFastLane]     IsFastLane   static
# 3           [Activity, Following List, App]            App   static
# 4    [Activity, Following List, IsFastLane]     IsFastLane   static
# ..                                      ...            ...      ...
# 126                          [AddYoursText]   AddYoursText     list
# 127                           [Description]    Description     list
# 128                                  [Name]           Name     list
# 129                              [Platform]       Platform     list
# 130                         [Profile Photo]  Profile Photo     list
#
# [131 rows x 21 columns]
# FINISH: clean_and_store()
# TT_json_structure_MvdV.json
# FINISH: loading_data()
# FINISH: flatten_json()
# FINISH: process_col_path()
# FINISH: remove_intermediate_rows()
# FINISH: extract_path()
# FINISH: list_path()
# /tmp/ipykernel_24409/2138702084.py:96: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace(r'^\s*$', np.nan, regex=True)
#         col_path_0                  col_path_1 col_path_1_LIST  \
# 0     Ads and data                Ad Interests         NO LIST
# 1     Ads and data  Instant Form Ads Responses         NO LIST
# 2     Ads and data         Off TikTok Activity         NO LIST
# 3     App Settings                  Block List         NO LIST
# 4     App Settings                  Block List         NO LIST
# ..             ...                         ...             ...
# 117  Your Activity               Watch History         NO LIST
# 118        Profile                Profile Info         NO LIST
# 119        Profile                Profile Info         NO LIST
# 120        Profile                Profile Info         NO LIST
# 121        Profile                Profile Info         NO LIST
#
#                     col_path_2 col_path_2_LIST    col_path_3 col_path_3_LIST  \
# 0         AdInterestCategories         NO LIST           NaN             NaN
# 1                ResponsesList         NO LIST           NaN             NaN
# 2    OffTikTokActivityDataList         NO LIST           NaN             NaN
# 3                          App         NO LIST           NaN             NaN
# 4                    BlockList         NO LIST           NaN             NaN
# ..                         ...             ...           ...             ...
# 117                  VideoList            LIST          Link         NO LIST
# 118                 ProfileMap         NO LIST  PlatformInfo            LIST
# 119                 ProfileMap         NO LIST  PlatformInfo            LIST
# 120                 ProfileMap         NO LIST  PlatformInfo            LIST
# 121                 ProfileMap         NO LIST  PlatformInfo            LIST
#
#         col_path_4 col_path_4_LIST  col_path_5  ...  col_path_6  \
# 0              NaN             NaN         NaN  ...         NaN
# 1              NaN             NaN         NaN  ...         NaN
# 2              NaN             NaN         NaN  ...         NaN
# 3              NaN             NaN         NaN  ...         NaN
# 4              NaN             NaN         NaN  ...         NaN
# ..             ...             ...         ...  ...         ...
# 117            NaN             NaN         NaN  ...         NaN
# 118    Description         NO LIST         NaN  ...         NaN
# 119           Name         NO LIST         NaN  ...         NaN
# 120       Platform         NO LIST         NaN  ...         NaN
# 121  Profile Photo         NO LIST         NaN  ...         NaN
#
#      col_path_6_LIST  col_path_0_LIST   last_valid_index data_type  \
# 0                NaN          NO LIST  col_path_2_values    string
# 1                NaN          NO LIST  col_path_2_values    object
# 2                NaN          NO LIST  col_path_2_values    object
# 3                NaN          NO LIST  col_path_2_values    number
# 4                NaN          NO LIST  col_path_2_values    object
# ..               ...              ...                ...       ...
# 117              NaN          NO LIST  col_path_3_values    string
# 118              NaN          NO LIST  col_path_4_values    string
# 119              NaN          NO LIST  col_path_4_values    string
# 120              NaN          NO LIST  col_path_4_values    string
# 121              NaN          NO LIST  col_path_4_values    string
#
#                                                   path  \
# 0    [Ads and data, Ad Interests, AdInterestCategor...
# 1    [Ads and data, Instant Form Ads Responses, Res...
# 2    [Ads and data, Off TikTok Activity, OffTikTokA...
# 3                      [App Settings, Block List, App]
# 4                [App Settings, Block List, BlockList]
# ..                                                 ...
# 117    [Your Activity, Watch History, VideoList, Link]
# 118  [Profile, Profile Info, ProfileMap, PlatformIn...
# 119  [Profile, Profile Info, ProfileMap, PlatformIn...
# 120  [Profile, Profile Info, ProfileMap, PlatformIn...
# 121  [Profile, Profile Info, ProfileMap, PlatformIn...
#
#                                              list_path  \
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 117          [Your Activity, Watch History, VideoList]
# 118  [Profile, Profile Info, ProfileMap, PlatformInfo]
# 119  [Profile, Profile Info, ProfileMap, PlatformInfo]
# 120  [Profile, Profile Info, ProfileMap, PlatformInfo]
# 121  [Profile, Profile Info, ProfileMap, PlatformInfo]
#
#                                          subfield_path  \
# 0    [Ads and data, Ad Interests, AdInterestCategor...
# 1    [Ads and data, Instant Form Ads Responses, Res...
# 2    [Ads and data, Off TikTok Activity, OffTikTokA...
# 3                      [App Settings, Block List, App]
# 4                [App Settings, Block List, BlockList]
# ..                                                 ...
# 117                                             [Link]
# 118                                      [Description]
# 119                                             [Name]
# 120                                         [Platform]
# 121                                    [Profile Photo]
#
#                    column_name var_type
# 0         AdInterestCategories   static
# 1                ResponsesList   static
# 2    OffTikTokActivityDataList   static
# 3                          App   static
# 4                    BlockList   static
# ..                         ...      ...
# 117                       Link     list
# 118                Description     list
# 119                       Name     list
# 120                   Platform     list
# 121              Profile Photo     list
#
# [122 rows x 21 columns]
# FINISH: clean_and_store()
# tiktok_takeout_dutch_structure.json
# FINISH: loading_data()
# FINISH: flatten_json()
# FINISH: process_col_path()
# FINISH: remove_intermediate_rows()
# FINISH: extract_path()
# FINISH: list_path()
# /tmp/ipykernel_24409/2138702084.py:96: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace(r'^\s*$', np.nan, regex=True)
#     col_path_0           col_path_1 col_path_1_LIST  col_path_2  \
# 0     Activity      Favorite Videos         NO LIST         App
# 1     Activity        Follower List         NO LIST         App
# 2     Activity        Follower List         NO LIST  IsFastLane
# 3     Activity       Following List         NO LIST         App
# 4     Activity       Following List         NO LIST  IsFastLane
# ..         ...                  ...             ...         ...
# 126      Video               Videos         NO LIST   VideoList
# 127    Profile  Profile Information         NO LIST  ProfileMap
# 128    Profile  Profile Information         NO LIST  ProfileMap
# 129    Profile  Profile Information         NO LIST  ProfileMap
# 130    Profile  Profile Information         NO LIST  ProfileMap
#
#     col_path_2_LIST    col_path_3 col_path_3_LIST     col_path_4  \
# 0           NO LIST           NaN             NaN            NaN
# 1           NO LIST           NaN             NaN            NaN
# 2           NO LIST           NaN             NaN            NaN
# 3           NO LIST           NaN             NaN            NaN
# 4           NO LIST           NaN             NaN            NaN
# ..              ...           ...             ...            ...
# 126            LIST  AddYoursText         NO LIST            NaN
# 127         NO LIST  PlatformInfo            LIST    Description
# 128         NO LIST  PlatformInfo            LIST           Name
# 129         NO LIST  PlatformInfo            LIST       Platform
# 130         NO LIST  PlatformInfo            LIST  Profile Photo
#
#     col_path_4_LIST  col_path_5  ...  col_path_6  col_path_6_LIST  \
# 0               NaN         NaN  ...         NaN              NaN
# 1               NaN         NaN  ...         NaN              NaN
# 2               NaN         NaN  ...         NaN              NaN
# 3               NaN         NaN  ...         NaN              NaN
# 4               NaN         NaN  ...         NaN              NaN
# ..              ...         ...  ...         ...              ...
# 126             NaN         NaN  ...         NaN              NaN
# 127         NO LIST         NaN  ...         NaN              NaN
# 128         NO LIST         NaN  ...         NaN              NaN
# 129         NO LIST         NaN  ...         NaN              NaN
# 130         NO LIST         NaN  ...         NaN              NaN
#
#      col_path_0_LIST   last_valid_index data_type  \
# 0            NO LIST  col_path_2_values    number
# 1            NO LIST  col_path_2_values    number
# 2            NO LIST  col_path_2_values   boolean
# 3            NO LIST  col_path_2_values    number
# 4            NO LIST  col_path_2_values   boolean
# ..               ...                ...       ...
# 126          NO LIST  col_path_3_values    string
# 127          NO LIST  col_path_4_values    string
# 128          NO LIST  col_path_4_values    string
# 129          NO LIST  col_path_4_values    string
# 130          NO LIST  col_path_4_values    string
#
#                                                   path  \
# 0                     [Activity, Favorite Videos, App]
# 1                       [Activity, Follower List, App]
# 2                [Activity, Follower List, IsFastLane]
# 3                      [Activity, Following List, App]
# 4               [Activity, Following List, IsFastLane]
# ..                                                 ...
# 126           [Video, Videos, VideoList, AddYoursText]
# 127  [Profile, Profile Information, ProfileMap, Pla...
# 128  [Profile, Profile Information, ProfileMap, Pla...
# 129  [Profile, Profile Information, ProfileMap, Pla...
# 130  [Profile, Profile Information, ProfileMap, Pla...
#
#                                              list_path  \
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 126                         [Video, Videos, VideoList]
# 127  [Profile, Profile Information, ProfileMap, Pla...
# 128  [Profile, Profile Information, ProfileMap, Pla...
# 129  [Profile, Profile Information, ProfileMap, Pla...
# 130  [Profile, Profile Information, ProfileMap, Pla...
#
#                               subfield_path    column_name var_type
# 0          [Activity, Favorite Videos, App]            App   static
# 1            [Activity, Follower List, App]            App   static
# 2     [Activity, Follower List, IsFastLane]     IsFastLane   static
# 3           [Activity, Following List, App]            App   static
# 4    [Activity, Following List, IsFastLane]     IsFastLane   static
# ..                                      ...            ...      ...
# 126                          [AddYoursText]   AddYoursText     list
# 127                           [Description]    Description     list
# 128                                  [Name]           Name     list
# 129                              [Platform]       Platform     list
# 130                         [Profile Photo]  Profile Photo     list
#
# [131 rows x 21 columns]
# FINISH: clean_and_store()

# %% [markdown]
# ## Merge all data structures into one schema_df

# %%
# Path to the folder containing CSV files
output_path = f"{main_path}TikTok/Output"

# Get a list of all CSV files in the folder
csv_files = list(Path(output_path).glob("*.csv"))

# Load all CSVs into a list of DataFrames
dfs = [pd.read_csv(file) for file in csv_files]

# Concatenate all DataFrames
merged_df = pd.concat(dfs, axis=0, ignore_index=True)

# Drop rows that are completely identical across all columns
merged_df = merged_df.drop_duplicates()
display(merged_df)
# Out:
#             column_name                                               path  \
# 0                   App             ['Activity', 'Favorite Videos', 'App']
# 1                   App               ['Activity', 'Follower List', 'App']
# 2            IsFastLane        ['Activity', 'Follower List', 'IsFastLane']
# 3                   App              ['Activity', 'Following List', 'App']
# 4            IsFastLane       ['Activity', 'Following List', 'IsFastLane']
# ..                  ...                                                ...
# 913  AIGeneratedContent  ['Video', 'RecentlyDeletedPosts', 'PostList', ...
# 914               Sound  ['Video', 'RecentlyDeletedPosts', 'PostList', ...
# 915            Location  ['Video', 'RecentlyDeletedPosts', 'PostList', ...
# 916               Title  ['Video', 'RecentlyDeletedPosts', 'PostList', ...
# 917        AddYoursText  ['Video', 'RecentlyDeletedPosts', 'PostList', ...
#
#                                          list_path  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ..                                             ...
# 913  ['Video', 'RecentlyDeletedPosts', 'PostList']
# 914  ['Video', 'RecentlyDeletedPosts', 'PostList']
# 915  ['Video', 'RecentlyDeletedPosts', 'PostList']
# 916  ['Video', 'RecentlyDeletedPosts', 'PostList']
# 917  ['Video', 'RecentlyDeletedPosts', 'PostList']
#
#                                     subfield_path var_type data_type
# 0          ['Activity', 'Favorite Videos', 'App']   static    number
# 1            ['Activity', 'Follower List', 'App']   static    number
# 2     ['Activity', 'Follower List', 'IsFastLane']   static   boolean
# 3           ['Activity', 'Following List', 'App']   static    number
# 4    ['Activity', 'Following List', 'IsFastLane']   static   boolean
# ..                                            ...      ...       ...
# 913                        ['AIGeneratedContent']     list    string
# 914                                     ['Sound']     list    string
# 915                                  ['Location']     list    string
# 916                                     ['Title']     list    string
# 917                              ['AddYoursText']     list    string
#
# [271 rows x 6 columns]

# %% [markdown]
# ### Id creation

# %%
id_df = merged_df[['path', 'column_name']]
id_df = id_df.drop_duplicates()
id_df[ 'id'] = ''



for n in range( max_columns):
    duplicates = id_df[id_df.duplicated(subset='id', keep=False)]

    for i, row in duplicates.iterrows():
        path = row['path']
        path =  ast.literal_eval(path)
        path_zero = path[0]
        path_rest = path[-n:]  # Varies each loop to attempt uniqueness

        if path_zero in path_rest:
            id_list = path_rest
        
        else:

            id_list = [path_zero] + path_rest   
            
        new_id = ':'.join(id_list)

        id_df.at[i, 'id'] = new_id  # Properly update the DataFrame



merged_df = pd.merge(merged_df, id_df, on = ['path', 'column_name'], how = 'left')

col = merged_df.pop('id') 
merged_df.insert(0, 'id', col) 
#merged_df['id']= merged_df['id'].fillna(merged_df['variable'])

# %% [markdown]
# #### Format JSON paths

# %%
def to_json_list(x):
    # Skip missing values
    if pd.isna(x):
        return x
    # If it's already a list, just dump
    if isinstance(x, list):
        return json.dumps(x)
    # If it's a string that looks like a list
    if isinstance(x, str) and x.strip().startswith("[") and x.strip().endswith("]"):
        try:
            return json.dumps(ast.literal_eval(x))
        except Exception:
            return x  # leave as is if parsing fails
    # Otherwise just return the string
    return x

for col in ['path', 'list_path', 'subfield_path']:
    merged_df[col] = merged_df[col].apply(to_json_list)

# %% [markdown]
# #### ID duplicate flags

# %%
merged_df = merged_df.astype(str)
merged_df = merged_df.drop_duplicates()
dup = merged_df[merged_df.duplicated('id', keep= False)]
dup['duplicate_flag'] = 'Yes'
dup = dup[['id', 'duplicate_flag']]
merged_df = pd.merge(merged_df, dup, on = 'id', how = 'left')
merged_df['duplicate_flag'] = merged_df['duplicate_flag'].fillna(value = 'No')
# Out:
# /tmp/ipykernel_24409/2402599662.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dup['duplicate_flag'] = 'Yes'

# %% [markdown]
# ### Clean and Save

# %%
merged_df['json_name'] = ''
merged_df['file_path'] = ''

keep_columns = ['id', 'column_name', 
                 'path', 'list_path', 'subfield_path', 
                 'var_type', 'data_type', 'json_name', 'file_path', 'duplicate_flag']


merged_df = merged_df[keep_columns ]


merged_df = merged_df.drop_duplicates()


# Save the final merged DataFrame
merged_df.to_csv(f"{main_path}TikTok/Final/TT_Merged_structures.csv", index=False)
