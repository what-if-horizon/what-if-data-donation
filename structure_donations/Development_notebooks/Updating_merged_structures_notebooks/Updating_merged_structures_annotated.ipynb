# %%
import pandas as pd
from pathlib import Path 
import os
import glob
from datetime import datetime

main_path = "/home/rvissche/Nextcloud/What-If/what-if-data-donation/structure_donations/"

# %% [markdown]
# ## Load the annotated data for all platforms

# %%
# Folder containing CSVs
folder_annotated = f"{main_path}Annotated_Merged_Structures"

# Dictionary to hold DataFrames
dfs_annotated = {}

for file in os.listdir(folder_annotated):
    if file.endswith(".csv"):
        name = os.path.splitext(file)[0]
        path = os.path.join(folder_annotated, file)
        dfs_annotated[name] = pd.read_csv(path)

# %%
dfs_annotated.keys()
# Out:
# dict_keys(['YT_merged_structure_annotated', 'IG_merged_structure_annotated', 'X_merged_structure_annotated', 'TT_merged_structure_annotated', 'YT_merged_column_names_annotated', 'FB_merged_structure_annotated'])

# %% [markdown]
# ## Loading the (new) merged structures

# %%
folder_new = f"{main_path}Processed_structure_donations"

dfs_new = {}

for path in glob.glob(f"{folder_new}/**/Final/*_Merged_structures.csv", recursive=True):
    name = os.path.splitext(os.path.basename(path))[0]
    dfs_new[name] = pd.read_csv(path)


YT_column = os.path.join(folder_new, "Youtube/Column_names_final/YT_Merged_Column_Names.csv")
if os.path.exists(YT_column):
    name = os.path.splitext(os.path.basename(YT_column))[0]
    dfs_new[name] = pd.read_csv(YT_column)

# %% [markdown]
# ## Identify the new rows

# %%
new_rows_dict = {}

dict_dfs = {
    'YT_merged_structure_annotated': 'YT_Merged_structures',
    'IG_merged_structure_annotated': 'IG_Merged_structures',
    'TT_merged_structure_annotated': 'TT_Merged_structures',
    'FB_merged_structure_annotated': 'FB_Merged_structures',
    'X_merged_structure_annotated' : 'X_Merged_structures',
    'YT_merged_column_names_annotated': 'YT_Merged_Column_Names'

}

for k,v in dict_dfs.items():
    
    dfs_annotated[f'{k}'] = dfs_annotated[k].loc[:, ~dfs_annotated[k].columns.str.startswith('Unnamed')]


    merge_cols = list(dfs_annotated[k].columns)

    if 'keepID' in merge_cols:
        merge_cols.remove('keepID')
    if 'keep_id' in merge_cols:
        merge_cols.remove('keep_id')
    if 'date_added' in merge_cols:
        merge_cols.remove('date_added')

   
    new_rows_dict[f'{v}_new'] = dfs_new[v].merge(dfs_annotated[k], how="left", on = merge_cols, indicator=True).query('_merge == "left_only"').drop(columns=["_merge"])

    date_col = 'date_added'

    if date_col not in new_rows_dict[f'{v}_new'].columns:
        new_rows_dict[f'{v}_new'][date_col] = datetime.now().strftime("%Y-%m-%d")

# %% [markdown]
# ## Append the new rows to the annotated merged structure

# %%
for k,v in dict_dfs.items():

    date_col = 'date_added'
    if date_col not in dfs_annotated[f'{k}'].columns:
         dfs_annotated[f'{k}'][date_col] = 'pre-trial'
    
    

    if v == 'YT_Merged_Column_Names':
        merge_cols = ['File_name', 'Column_names']
        use_cols = ['File_name', 'Column_names', 'keepID']

    else: 
        merge_cols = ['json_name', 'path', 'file_path']
        use_cols = ['json_name', 'path', 'file_path', 'keepID']

        file_path = 'file_path'
        if file_path not in dfs_annotated[f'{k}'].columns:
            dfs_annotated[f'{k}'][file_path] = ''
    
    
        
    new_rows_dict[f'{v}_new'] = new_rows_dict[f'{v}_new'].drop('keepID', axis = 1)
    display(new_rows_dict[f'{v}_new'].columns)
    new_rows_dict[f'{v}_new'] = new_rows_dict[f'{v}_new'].merge(dfs_annotated[f'{k}'][use_cols], on = merge_cols, how = 'left')
  
    
    dfs_annotated[f'{k}'] = pd.concat([dfs_annotated[f'{k}'], new_rows_dict[f'{v}_new']], ignore_index=True)
    display(dfs_annotated[f'{k}'])
# Out:
# Index(['json_name', 'id', 'column_name', 'path', 'list_path', 'subfield_path',
#        'var_type', 'data_type', 'file_path', 'duplicate_flag', 'date_added'],
#       dtype='object')
#                             json_name  \
# 0         istoricul căutărilor.json
# 1         istoricul căutărilor.json
# 2         istoricul căutărilor.json
# 3         istoricul căutărilor.json
# 4         istoricul căutărilor.json
# ..                                ...
# 123        historial-de-búsqueda.json
# 124  historial-de-reproducciones.json
# 125                watch-history.json
# 126             zoekgeschiedenis.json
# 127             zoekgeschiedenis.json
#
#                                            id       column_name  \
# 0               istoricul căutărilor:header            header
# 1                istoricul căutărilor:title             title
# 2             istoricul căutărilor:titleUrl          titleUrl
# 3          istoricul căutărilor:description       description
# 4                 istoricul căutărilor:time              time
# ..                                        ...               ...
# 123    historial-de-búsqueda:activityControls  activityControls
# 124  historial-de-reproducciones:details:name              name
# 125                watch-history:details:name              name
# 126              zoekgeschiedenis:description       description
# 127                     zoekgeschiedenis:name              name
#
#                      path    list_path         subfield_path var_type  \
# 0              ["header"]           []            ["header"]     list
# 1               ["title"]           []             ["title"]     list
# 2            ["titleUrl"]           []          ["titleUrl"]     list
# 3         ["description"]           []       ["description"]     list
# 4                ["time"]           []              ["time"]     list
# ..                    ...          ...                   ...      ...
# 123  ["activityControls"]           []  ["activityControls"]     list
# 124   ["details", "name"]  ["details"]              ["name"]     list
# 125   ["details", "name"]  ["details"]              ["name"]     list
# 126       ["description"]           []       ["description"]     list
# 127   ["details", "name"]  ["details"]              ["name"]     list
#
#     data_type                                   file_path duplicate_flag  \
# 0      string         istoric/istoricul căutărilor.json             No
# 1      string         istoric/istoricul căutărilor.json             No
# 2      string         istoric/istoricul căutărilor.json             No
# 3      string         istoric/istoricul căutărilor.json             No
# 4      string         istoric/istoricul căutărilor.json             No
# ..        ...                                         ...            ...
# 123    string        historial/historial-de-búsqueda.json             No
# 124    string  historial/historial-de-reproducciones.json             No
# 125    string                  history/watch-history.json            Yes
# 126    string          geschiedenis/zoekgeschiedenis.json             No
# 127    string          geschiedenis/zoekgeschiedenis.json             No
#
#                               keepID date_added
# 0              search-history:header  pre-trial
# 1               search-history:title  pre-trial
# 2            search-history:titleUrl  pre-trial
# 3         search-history:description  pre-trial
# 4                search-history:time  pre-trial
# ..                               ...        ...
# 123  search-history:activityControls  pre-trial
# 124       watch-history:details:name  pre-trial
# 125       watch-history:details:name  pre-trial
# 126       search-history:description  pre-trial
# 127              search-history:name  pre-trial
#
# [128 rows x 12 columns]
# Index(['json_name', 'id', 'column_name', 'path', 'list_path', 'subfield_path',
#        'var_type', 'data_type', 'file_path', 'duplicate_flag', 'date_added'],
#       dtype='object')
#                 json_name                                                 id  \
# 0          message_1.json          message_requests:username:message_1:title
# 1          message_1.json  message_requests:username:message_1:is_still_p...
# 2          message_1.json    message_requests:username:message_1:thread_path
# 3          message_1.json    message_requests:username:message_1:magic_words
# 4          message_1.json                      username:message_1:is_pending
# ..                    ...                                                ...
# 676  possible_emails.json        information_about_you:possible_emails:title
# 677  possible_emails.json  information_about_you:possible_emails:media_li...
# 678  possible_emails.json         information_about_you:possible_emails:href
# 679  possible_emails.json        information_about_you:possible_emails:value
# 680  possible_emails.json    information_about_you:possible_emails:timestamp
#
#               column_name                                               path  \
# 0                   title                                          ["title"]
# 1    is_still_participant                           ["is_still_participant"]
# 2             thread_path                                    ["thread_path"]
# 3             magic_words                                    ["magic_words"]
# 4              is_pending                                     ["is_pending"]
# ..                    ...                                                ...
# 676                 title         ["inferred_data_inferred_emails", "title"]
# 677       media_list_data  ["inferred_data_inferred_emails", "media_list_...
# 678                  href  ["inferred_data_inferred_emails", "string_list...
# 679                 value  ["inferred_data_inferred_emails", "string_list...
# 680             timestamp  ["inferred_data_inferred_emails", "string_list...
#
#                                              list_path  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 676                  ["inferred_data_inferred_emails"]
# 677                  ["inferred_data_inferred_emails"]
# 678  ["inferred_data_inferred_emails", "string_list...
# 679  ["inferred_data_inferred_emails", "string_list...
# 680  ["inferred_data_inferred_emails", "string_list...
#
#                 subfield_path var_type data_type  \
# 0                   ["title"]   static    string
# 1    ["is_still_participant"]   static   boolean
# 2             ["thread_path"]   static    string
# 3             ["magic_words"]   static     array
# 4              ["is_pending"]   static   boolean
# ..                        ...      ...       ...
# 676                 ["title"]     list    string
# 677       ["media_list_data"]     list     array
# 678                  ["href"]     list    string
# 679                 ["value"]     list    string
# 680             ["timestamp"]     list    number
#
#                                              file_path duplicate_flag keepID  \
# 0    your_instagram_activity/messages/message_reque...             No    NaN
# 1    your_instagram_activity/messages/message_reque...             No    NaN
# 2    your_instagram_activity/messages/message_reque...             No    NaN
# 3    your_instagram_activity/messages/message_reque...             No    NaN
# 4    your_instagram_activity/messages/message_reque...             No    NaN
# ..                                                 ...            ...    ...
# 676  personal_information/information_about_you/pos...             No    NaN
# 677  personal_information/information_about_you/pos...             No    NaN
# 678  personal_information/information_about_you/pos...             No    NaN
# 679  personal_information/information_about_you/pos...             No    NaN
# 680  personal_information/information_about_you/pos...             No    NaN
#
#     date_added
# 0    pre-trial
# 1    pre-trial
# 2    pre-trial
# 3    pre-trial
# 4    pre-trial
# ..         ...
# 676  pre-trial
# 677  pre-trial
# 678  pre-trial
# 679  pre-trial
# 680  pre-trial
#
# [681 rows x 12 columns]
# Index(['id', 'column_name', 'path', 'list_path', 'subfield_path', 'var_type',
#        'data_type', 'json_name', 'file_path', 'duplicate_flag', 'date_added'],
#       dtype='object')
#                                                     id  \
# 0    Tiktok Live:Go Live Settings:SettingsMap:Peopl...
# 1    Tiktok Live:Go Live Settings:SettingsMap:Peopl...
# 2    Tiktok Live:Go Live Settings:SettingsMap:Hide ...
# 3    Tiktok Live:Go Live Settings:SettingsMap:Hide ...
# 4                    Comment:Comments:CommentsList:url
# ..                                                 ...
# 278  Activity:Activity Summary:ActivitySummaryMap:v...
# 279  Activity:Activity Summary:ActivitySummaryMap:note
# 280          Video:Videos:VideoList:AIGeneratedContent
# 281            Post:Posts:VideoList:AIGeneratedContent
# 282  Video:RecentlyDeletedPosts:PostList:AIGenerate...
#
#                                            column_name  \
# 0            People you assigned to moderate your LIVE
# 1            People you assigned to moderate your LIVE
# 2    Hide comments that contain the following keywo...
# 3    Hide comments that contain the following keywo...
# 4                                                  url
# ..                                                 ...
# 278          videosCommentedOnSinceAccountRegistration
# 279                                               note
# 280                                 AIGeneratedContent
# 281                                 AIGeneratedContent
# 282                                 AIGeneratedContent
#
#                                                   path  \
# 0    ["Tiktok Live", "Go Live Settings", "SettingsM...
# 1    ["Tiktok Live", "Go Live Settings", "SettingsM...
# 2    ["Tiktok Live", "Go Live Settings", "SettingsM...
# 3    ["Tiktok Live", "Go Live Settings", "SettingsM...
# 4       ["Comment", "Comments", "CommentsList", "url"]
# ..                                                 ...
# 278  ["Activity", "Activity Summary", "ActivitySumm...
# 279  ["Activity", "Activity Summary", "ActivitySumm...
# 280  ["Video", "Videos", "VideoList", "AIGeneratedC...
# 281  ["Post", "Posts", "VideoList", "AIGeneratedCon...
# 282  ["Video", "RecentlyDeletedPosts", "PostList", ...
#
#                                              list_path  \
# 0    ["Tiktok Live", "Go Live Settings", "SettingsM...
# 1    ["Tiktok Live", "Go Live Settings", "SettingsM...
# 2    ["Tiktok Live", "Go Live Settings", "SettingsM...
# 3    ["Tiktok Live", "Go Live Settings", "SettingsM...
# 4              ["Comment", "Comments", "CommentsList"]
# ..                                                 ...
# 278                                                NaN
# 279                                                NaN
# 280                   ["Video", "Videos", "VideoList"]
# 281                     ["Post", "Posts", "VideoList"]
# 282      ["Video", "RecentlyDeletedPosts", "PostList"]
#
#                                          subfield_path var_type data_type  \
# 0                                                   []     list     array
# 1                                                   []     list     array
# 2                                                   []     list     array
# 3                                                   []     list     array
# 4                                              ["url"]     list    string
# ..                                                 ...      ...       ...
# 278  ["Activity", "Activity Summary", "ActivitySumm...   static    number
# 279  ["Activity", "Activity Summary", "ActivitySumm...   static    string
# 280                             ["AIGeneratedContent"]     list    string
# 281                             ["AIGeneratedContent"]     list    string
# 282                             ["AIGeneratedContent"]     list    string
#
#      json_name duplicate_flag  \
# 0          NaN            Yes
# 1          NaN            Yes
# 2          NaN            Yes
# 3          NaN            Yes
# 4          NaN             No
# ..         ...            ...
# 278        NaN             No
# 279        NaN             No
# 280        NaN             No
# 281        NaN             No
# 282        NaN             No
#
#                                                 keepID date_added file_path
# 0    Tiktok Live:Go Live Settings:SettingsMap:Peopl...  pre-trial
# 1    Tiktok Live:Go Live Settings:SettingsMap:Peopl...  pre-trial
# 2    Tiktok Live:Go Live Settings:SettingsMap:Hide ...  pre-trial
# 3    Tiktok Live:Go Live Settings:SettingsMap:Hide ...  pre-trial
# 4                    Comment:Comments:CommentsList:url  pre-trial
# ..                                                 ...        ...       ...
# 278  Activity:Activity Summary:ActivitySummaryMap:v...  pre-trial
# 279                                                NaN  pre-trial
# 280          Video:Videos:VideoList:AIGeneratedContent  pre-trial
# 281          Video:Videos:VideoList:AIGeneratedContent  pre-trial
# 282                                                NaN  pre-trial
#
# [283 rows x 12 columns]
# Index(['json_name', 'id', 'column_name', 'path', 'list_path', 'subfield_path',
#        'var_type', 'data_type', 'file_path', 'duplicate_flag', 'date_added'],
#       dtype='object')
#                                             json_name  \
# 0                                browser_cookies.json
# 1                                      message_1.json
# 2                                      message_1.json
# 3                                      message_1.json
# 4                                      message_1.json
# ...                                               ...
# 5686                         likes_and_reactions.json
# 5687                         likes_and_reactions.json
# 5688                         likes_and_reactions.json
# 5689  your_posts__check_ins__photos_and_videos_1.json
# 5690  your_posts__check_ins__photos_and_videos_1.json
#
#                                                      id  \
# 0     security_and_login_information:browser_cookies...
# 1     your_facebook_activity:messages:filtered_threa...
# 2     your_facebook_activity:messages:filtered_threa...
# 3     your_facebook_activity:messages:filtered_threa...
# 4     your_facebook_activity:messages:filtered_threa...
# ...                                                 ...
# 5686  profile_information:your_facebook_activity:com...
# 5687  profile_information:your_facebook_activity:com...
# 5688  profile_information:your_facebook_activity:com...
# 5689  profile_information:your_facebook_activity:pos...
# 5690  profile_information:your_facebook_activity:pos...
#
#                    column_name                                           path  \
# 0     YvP_********************  ["datr_stats_v2", "YvP_********************"]
# 1                        title                                      ["title"]
# 2                        title                                      ["title"]
# 3                        title                                      ["title"]
# 4                        title                                      ["title"]
# ...                        ...                                            ...
# 5686                 timestamp                                  ["timestamp"]
# 5687                     media                                      ["media"]
# 5688                      fbid                                       ["fbid"]
# 5689                 timestamp                                  ["timestamp"]
# 5690                     title                                      ["title"]
#
#      list_path                                  subfield_path var_type  \
# 0          NaN  ["datr_stats_v2", "YvP_********************"]   static
# 1          NaN                                      ["title"]   static
# 2          NaN                                      ["title"]   static
# 3          NaN                                      ["title"]   static
# 4          NaN                                      ["title"]   static
# ...        ...                                            ...      ...
# 5686       NaN                                  ["timestamp"]   static
# 5687       NaN                                      ["media"]   static
# 5688       NaN                                       ["fbid"]   static
# 5689       NaN                                  ["timestamp"]   static
# 5690       NaN                                      ["title"]   static
#
#      data_type                                          file_path  \
# 0       number  security_and_login_information/browser_cookies...
# 1       string  your_facebook_activity/messages/filtered_threa...
# 2       string  your_facebook_activity/messages/filtered_threa...
# 3       string  your_facebook_activity/messages/filtered_threa...
# 4       string  your_facebook_activity/messages/filtered_threa...
# ...        ...                                                ...
# 5686    number  personal_information/profile_information/your_...
# 5687     array  personal_information/profile_information/your_...
# 5688    string  personal_information/profile_information/your_...
# 5689    number  personal_information/profile_information/your_...
# 5690    string  personal_information/profile_information/your_...
#
#      duplicate_flag                                             keepID  \
# 0                No                                                NaN
# 1               Yes                                                NaN
# 2               Yes                                                NaN
# 3               Yes                                                NaN
# 4               Yes                                                NaN
# ...             ...                                                ...
# 5686             No  your_facebook_activity:comments_and_reactions:...
# 5687             No  your_facebook_activity:comments_and_reactions:...
# 5688             No  your_facebook_activity:comments_and_reactions:...
# 5689             No  your_facebook_activity:posts:your_posts__check...
# 5690             No  your_facebook_activity:posts:your_posts__check...
#
#      date_added
# 0     pre-trial
# 1     pre-trial
# 2     pre-trial
# 3     pre-trial
# 4     pre-trial
# ...         ...
# 5686        NaN
# 5687        NaN
# 5688        NaN
# 5689        NaN
# 5690        NaN
#
# [5691 rows x 12 columns]
# Index(['json_name', 'id', 'column_name', 'path', 'list_path', 'subfield_path',
#        'var_type', 'data_type', 'file_path', 'duplicate_flag', 'date_added'],
#       dtype='object')
#                               id                       keepID  \
# 0             manifest:accountId                          NaN
# 1              manifest:userName                          NaN
# 2           manifest:displayName                          NaN
# 3             manifest:sizeBytes                          NaN
# 4        manifest:generationDate      manifest:generationDate
# ..                           ...                          ...
# 629  personalization:advertisers  personalization:advertisers
# 630  personalization:advertisers  personalization:advertisers
# 631  personalization:advertisers  personalization:advertisers
# 632                     ip-audit                          NaN
# 633           screen-name-change                          NaN
#
#                  json_name     column_name  \
# 0              manifest.js       accountId
# 1              manifest.js        userName
# 2              manifest.js     displayName
# 3              manifest.js       sizeBytes
# 4              manifest.js  generationDate
# ..                     ...             ...
# 629     personalization.js     advertisers
# 630     personalization.js     advertisers
# 631     personalization.js     advertisers
# 632            ip-audit.js             NaN
# 633  screen-name-change.js             NaN
#
#                                                   path list_path  \
# 0                            ["userInfo", "accountId"]       NaN
# 1                             ["userInfo", "userName"]       NaN
# 2                          ["userInfo", "displayName"]       NaN
# 3                         ["archiveInfo", "sizeBytes"]       NaN
# 4                    ["archiveInfo", "generationDate"]       NaN
# ..                                                 ...       ...
# 629  ["p13nData", "interests", "audienceAndAdvertis...       NaN
# 630  ["p13nData", "interests", "audienceAndAdvertis...       NaN
# 631  ["p13nData", "interests", "audienceAndAdvertis...       NaN
# 632                                                NaN       NaN
# 633                                                NaN       NaN
#
#                                          subfield_path var_type data_type  \
# 0                            ["userInfo", "accountId"]   static    string
# 1                             ["userInfo", "userName"]   static    string
# 2                          ["userInfo", "displayName"]   static    string
# 3                         ["archiveInfo", "sizeBytes"]   static    string
# 4                    ["archiveInfo", "generationDate"]   static    string
# ..                                                 ...      ...       ...
# 629  ["p13nData", "interests", "audienceAndAdvertis...   static    string
# 630  ["p13nData", "interests", "audienceAndAdvertis...   static     array
# 631  ["p13nData", "interests", "audienceAndAdvertis...   static    string
# 632                                                NaN     skip       NaN
# 633                                                NaN     skip       NaN
#
#                       file_path duplicate_flag date_added
# 0              data/manifest.js             No  pre-trial
# 1              data/manifest.js             No  pre-trial
# 2              data/manifest.js             No  pre-trial
# 3              data/manifest.js             No  pre-trial
# 4              data/manifest.js             No  pre-trial
# ..                          ...            ...        ...
# 629     data/personalization.js            Yes  pre-trial
# 630     data/personalization.js            Yes  pre-trial
# 631     data/personalization.js            Yes  pre-trial
# 632            data/ip-audit.js             No  pre-trial
# 633  data/screen-name-change.js             No  pre-trial
#
# [634 rows x 12 columns]
# Index(['File_name', 'Column_names', 'id', 'date_added'], dtype='object')
#                                      File_name  \
# 0                      channel URL configs.csv
# 1                      channel URL configs.csv
# 2                      channel URL configs.csv
# 3    channel community moderation settings.csv
# 4                     channel feature data.csv
# ..                                         ...
# 287                    Watch later-vídeos.csv
# 288                    Watch later-vídeos.csv
# 289                        crochet-vídeos.csv
# 290                        crochet-vídeos.csv
# 291            gegevens voor kanaalfunctie.csv
#
#                                           Column_names  \
# 0                                           Channel ID
# 1                            Channel Vanity URL 1 Name
# 2                            Channel Vanity URL 2 Name
# 3                                           Channel ID
# 4                                           Channel ID
# ..                                                 ...
# 287                                        ID de vídeo
# 288  Marca de tiempo de creación de la lista de rep...
# 289                                        ID de vídeo
# 290  Marca de tiempo de creación de la lista de rep...
# 291     Automatische moderatie in live chat van kanaal
#
#                                                     id  \
# 0                       channel_URL_configs:Channel_ID
# 1        channel_URL_configs:Channel_Vanity_URL_1_Name
# 2        channel_URL_configs:Channel_Vanity_URL_2_Name
# 3     channel_community_moderation_settings:Channel_ID
# 4                      channel_feature_data:Channel_ID
# ..                                                 ...
# 287                    Watch_later-vídeos:ID_de_vídeo
# 288  Watch_later-vídeos:Marca_de_tiempo_de_creació...
# 289                        crochet-vídeos:ID_de_vídeo
# 290  crochet-vídeos:Marca_de_tiempo_de_creación_de...
# 291  gegevens_voor_kanaalfunctie:Automatische_moder...
#
#                                                 keepID date_added
# 0                       channel_URL_configs:Channel_ID  pre-trial
# 1        channel_URL_configs:Channel_Vanity_URL_1_Name  pre-trial
# 2        channel_URL_configs:Channel_Vanity_URL_2_Name  pre-trial
# 3     channel_community_moderation_settings:Channel_ID  pre-trial
# 4                      channel_feature_data:Channel_ID  pre-trial
# ..                                                 ...        ...
# 287                        Watch_later-videos:Video_ID  pre-trial
# 288  Watch_later-videos:Playlist_Video_Creation_Tim...  pre-trial
# 289                            crochet-videos:Video_ID  pre-trial
# 290   crochet-videos:Playlist_Video_Creation_Timestamp  pre-trial
# 291  channel_feature_data:Channel_Auto_Moderation_i...  pre-trial
#
# [292 rows x 5 columns]

# %% [markdown]
# ## Save annotated merged structures

# %%
# Assume dfs_dict is your dictionary of DataFrames
for key, df in dfs_annotated.items():
    # Create a filename from the key
    filename = f"{key}.csv"
    path = os.path.join(folder_annotated, filename)
    
    # Save DataFrame to CSV
    df.to_csv(path, index=False)
    print(f"Saved {filename} ({len(df)} rows)")
# Out:
# Saved YT_merged_structure_annotated.csv (128 rows)
# Saved IG_merged_structure_annotated.csv (681 rows)
# Saved X_merged_structure_annotated.csv (634 rows)
# Saved TT_merged_structure_annotated.csv (283 rows)
# Saved YT_merged_column_names_annotated.csv (292 rows)
# Saved FB_merged_structure_annotated.csv (5691 rows)
